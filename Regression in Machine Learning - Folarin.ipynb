# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
df = pd.read_csv("energydata_complete.csv")
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
# q12 = df[['T2', 'T6']]

# X = df[['T2']]
# y = df['T6'].values

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# lr = LinearRegression()
# lr.fit(X_train, y_train)

# %%
# y_pred = lr.predict(X_test)
# y_pred = y_pred.round(4)

# %%
# y_test = y_test.round(4)

# %%
# import sklearn.metrics

# r2_sc = (r2_score(y_test, y_pred))
# r2_sc

# %%
df.drop(columns = ["date", "lights"], inplace =True )

# %%
df.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
scaler = MinMaxScaler()

new_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
X= new_df.drop(columns = ["Appliances"])
y = new_df['Appliances']

# %%
X
# Out:
#              T1      RH_1        T2      RH_2        T3      RH_3        T4  \
# 0      0.327350  0.566187  0.225345  0.684038  0.215188  0.746066  0.351351
# 1      0.327350  0.541326  0.225345  0.682140  0.215188  0.748871  0.351351
# 2      0.327350  0.530502  0.225345  0.679445  0.215188  0.755569  0.344745
# 3      0.327350  0.524080  0.225345  0.678414  0.215188  0.758685  0.341441
# 4      0.327350  0.531419  0.225345  0.676727  0.215188  0.758685  0.341441
# ...         ...       ...       ...       ...       ...       ...       ...
# 19730  0.926786  0.537657  0.711655  0.606309  0.830841  0.579374  0.864865
# 19731  0.919747  0.536006  0.701769  0.607836  0.825302  0.582178  0.864865
# 19732  0.919747  0.538666  0.692651  0.627198  0.818378  0.603988  0.864865
# 19733  0.919747  0.549491  0.677054  0.634717  0.805085  0.585294  0.864865
# 19734  0.919747  0.538758  0.666171  0.632902  0.799546  0.579062  0.864865
#
# ...

# %%
y
# Out:
# 0        0.046729
# 1        0.046729
# 2        0.037383
# 3        0.037383
# 4        0.046729
#            ...
# 19730    0.084112
# 19731    0.074766
# 19732    0.242991
# 19733    0.383178
# 19734    0.392523
# Name: Appliances, Length: 19735, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
linear = LinearRegression()
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 0.05013281265858139

# %%
rss = np.sum(np.square(y_test - y_pred))
rss
# Out:
# 42.33443740799913

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 0.08455696097932426

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.20545493424595573

# %%
lmw = pd.Series(linear.coef_, X_train.columns).sort_values()
lmw = pd.DataFrame(lmw)
lmw = lmw.reset_index()
lmw.rename(columns = {"index": "Features", 0:"Linear Regression"}, inplace=True)
lmw
# Out:
#        Features  Linear Regression
# 0           rv2      -1.015533e+11
# 1          RH_2      -4.566132e-01
# 2         T_out      -3.217958e-01
# 3            T2      -2.361240e-01
# 4            T9      -1.899212e-01
# 5          RH_8      -1.575959e-01
# 6        RH_out      -7.765047e-02
# 7          RH_7      -4.462370e-02
# 8          RH_9      -3.980111e-02
# 9            T5      -1.565920e-02
# 10           T1      -3.281051e-03
# 11  Press_mm_hg       6.838751e-03
# 12           T7       1.032414e-02
# 13   Visibility       1.230614e-02
# 14         RH_5       1.599726e-02
# 15         RH_4       2.640099e-02
# 16           T4       2.900027e-02
# 17    Windspeed       2.918709e-02
# 18         RH_6       3.805716e-02
# 19         RH_3       9.598836e-02
# 20           T8       1.019952e-01
# 21    Tdewpoint       1.177209e-01
# 22           T6       2.363848e-01
# 23           T3       2.905510e-01
# 24         RH_1       5.535724e-01
# 25          rv1       1.015533e+11

# %%
lmw[lmw["Linear Regression"] == lmw["Linear Regression"].min()]
# Out:
#   Features  Linear Regression
# 0      rv2      -1.015533e+11

# %%
ridge = Ridge(alpha = 0.4)

# %%
ridge.fit(X_train, y_train)
new_p = ridge.predict(X_test)

# %%
n_rmse = np.sqrt(mean_squared_error(y_test, new_p))
n_rmse
# Out:
# 0.08753385704628003

# %%
las = Lasso(alpha = 0.001)
las.fit(X_train, y_train)
las_p = las.predict(X_test)

# %%
l_rmse = np.sqrt(mean_squared_error(y_test, las_p))
l_rmse
# Out:
# 0.09358170467245137

# %%
mw = pd.Series(las.coef_, X_train.columns).sort_values()
mw = pd.DataFrame(mw)
mw = mw.reset_index()
mw.rename(columns = {"index": "Features", 0:"Lasso"}, inplace=True)
mw
# Out:
#        Features     Lasso
# 0        RH_out -0.049557
# 1          RH_8 -0.000110
# 2            T1  0.000000
# 3     Tdewpoint  0.000000
# 4    Visibility  0.000000
# 5   Press_mm_hg -0.000000
# 6         T_out  0.000000
# 7          RH_9 -0.000000
# 8            T9 -0.000000
# 9            T8  0.000000
# 10         RH_7 -0.000000
# 11          rv1 -0.000000
# 12           T7 -0.000000
# 13           T6  0.000000
# 14         RH_5  0.000000
# 15           T5 -0.000000
# 16         RH_4  0.000000
# 17           T4 -0.000000
# 18         RH_3  0.000000
# 19           T3  0.000000
# 20         RH_2 -0.000000
# 21           T2  0.000000
# 22         RH_6 -0.000000
# 23          rv2 -0.000000
# 24    Windspeed  0.002912
# 25         RH_1  0.017880
